# %% [markdown]
# <a href="https://colab.research.google.com/github/Shady91-ML/Sonar-ML/blob/main/Sonar_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import libraries

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# Data pre-processing

# %%
#Loading data to Panda's dataframe
  #There is no header in csv file -> header=None
sonar_df = pd.read_csv('/content/Sonar_data.csv', header=None)

# %%
#Checking number of rows and columns in dataset
sonar_df.shape
# Out:
# (208, 61)

# %%
sonar_df.describe()
# Out:
#                0           1           2           3           4           5   \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832    0.053892    0.075202    0.104570
# std      0.022991    0.032960    0.038428    0.046528    0.055552    0.059105
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013350    0.016450    0.018950    0.024375    0.038050    0.067025
# 50%      0.022800    0.030800    0.034300    0.044050    0.062500    0.092150
# 75%      0.035550    0.047950    0.057950    0.064500    0.100275    0.134125
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#                6           7           8           9   ...          50  \
# count  208.000000  208.000000  208.000000  208.000000  ...  208.000000
# mean     0.121747    0.134799    0.178003    0.208259  ...    0.016069
# ...

# %%
#Checking how many Rocks and Metals are in dataset -> column 60
sonar_df[60].value_counts()
# Out:
# 60
# M    111
# R     97
# Name: count, dtype: int64
